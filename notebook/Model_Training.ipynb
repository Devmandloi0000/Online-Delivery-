# %%
import pandas  as pd
import numpy as np

# %%
# Data_ingestion step 
data = pd.read_csv("E:\\Working\\complete_task_25_aug\\notebook\\data\\finalTrain.csv")

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
df = data

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
df.shape
# Out:
# (45584, 20)

# %%
df.drop(['ID','Delivery_person_ID'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          43730 non-null  float64
#  1   Delivery_person_Ratings      43676 non-null  float64
#  2   Restaurant_latitude          45584 non-null  float64
#  3   Restaurant_longitude         45584 non-null  float64
#  4   Delivery_location_latitude   45584 non-null  float64
#  5   Delivery_location_longitude  45584 non-null  float64
#  6   Order_Date                   45584 non-null  object
#  7   Time_Orderd                  43853 non-null  object
#  8   Time_Order_picked            45584 non-null  object
#  9   Weather_conditions           44968 non-null  object
#  10  Road_traffic_density         44983 non-null  object
#  11  Vehicle_condition            45584 non-null  int64
#  12  Type_of_order                45584 non-null  object
#  13  Type_of_vehicle              45584 non-null  object
#  14  multiple_deliveries          44591 non-null  float64
#  15  Festival                     45356 non-null  object
#  16  City                         44384 non-null  object
#  17  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 6.3+ MB

# %% [markdown]
# Order_day

# %%
df['Order_day']=df['Order_Date'].str.split('-').str[0]
df['Order_month']=df['Order_Date'].str.split('-').str[1]
df['Order_year']=df['Order_Date'].str.split('-').str[2]
df.drop('Order_Date',axis=1,inplace=True)

# %%
df['Order_day']=df['Order_day'].astype(int)
df['Order_month']=df['Order_month'].astype(int)
df['Order_year']=df['Order_year'].astype(int)

# %% [markdown]
# Time_Order_picked

# %%
my_dict = {
"0.458333333" : "11:00",
"0.958333333" : "23:00",
"0.791666667" : "19:00",
"0.875" : "21:00",
"1" : "24:00",
"0.375" : "9:00",
"0.625" : "13:00",
"0.833333333" : "20:00",
"0.666666667" : "16:00",
"0.75" : "18:00",
"0.416666667" : "10:00",
"0.916666667" : "22:00",
"0.5" : "12:00",
"0.708333333": "17:00",
"0.541666667": "13:00",
"0.583333333": "14:00"}

# %%
df['Time_Orderd']=df['Time_Orderd'].replace(my_dict)

# %%
df.dropna(subset=['Time_Orderd'],inplace=True)

# %%
df['Time_Orderd']=df['Time_Orderd'].str.split(":").str[0].astype(int)*60 + df['Time_Orderd'].str.split(":").str[1].astype(int)

# %% [markdown]
# Time_Order_picked

# %%
df['Time_Order_picked']=df['Time_Order_picked'].replace(my_dict)

# %%
df['Time_Order_picked']=df['Time_Order_picked'].str.split(":").str[0].astype(int) * 60 + df['Time_Order_picked'].str.split(":").str[1].astype(int)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Time_Orderd  Time_Order_picked  \
# 0                    78.116106         1315               1330
# 1                    76.347589          895                905
# 2                    74.006619         1050               1060
# 3                    75.829346          560                570
# 4                    80.502929         1190               1205
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)  Order_day  Order_month  Order_year
# 0                46         12            2        2022
# 1                23         13            2        2022
# 2                21          4            3        2022
# 3                20         13            2        2022
# 4                41         14            2        2022

# %%
weather_map=['Sunny', 'Windy', 'Sandstorms', 'Cloudy', 'Stormy', 'Fog']
road_traffic_map=['Low', 'Medium', 'High', 'Jam']
type_order_map = ['Buffet', 'Drinks', 'Meal', 'Snack']
type_vehicle_map = ['electric_scooter','scooter', 'motorcycle']
festival_map = ['No', 'Yes']
city_map = ['Semi-Urban', 'Urban','Metropolitian']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43853 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          43639 non-null  float64
#  1   Delivery_person_Ratings      43585 non-null  float64
#  2   Restaurant_latitude          43853 non-null  float64
#  3   Restaurant_longitude         43853 non-null  float64
#  4   Delivery_location_latitude   43853 non-null  float64
#  5   Delivery_location_longitude  43853 non-null  float64
#  6   Time_Orderd                  43853 non-null  int32
#  7   Time_Order_picked            43853 non-null  int32
#  8   Weather_conditions           43853 non-null  object
#  9   Road_traffic_density         43853 non-null  object
#  10  Vehicle_condition            43853 non-null  int64
#  11  Type_of_order                43853 non-null  object
#  12  Type_of_vehicle              43853 non-null  object
#  13  multiple_deliveries          42910 non-null  float64
#  14  Festival                     43634 non-null  object
#  15  City                         42709 non-null  object
#  16  Time_taken (min)             43853 non-null  int64
#  17  Order_day                    43853 non-null  int32
#  18  Order_month                  43853 non-null  int32
#  19  Order_year                   43853 non-null  int32
# dtypes: float64(7), int32(5), int64(2), object(6)
# memory usage: 6.2+ MB

# %%
# Independent and Dependent features

X = df.drop(labels=["Time_taken (min)"],axis=1)
y = df[['Time_taken (min)']]

# %%
X
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                     36.0                      4.2            30.327968
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 0                 78.046106                   30.397968
# 1                 76.307589                   10.043064
# 2                 73.916619                   18.652450
# 3                 75.809346                   30.919584
# 4                 80.372929                   26.593504
# ...                     ...                         ...
# 45579             75.794257                   26.912328
# 45580              0.000000                    0.070000
# 45581             80.242439                   13.052394
# 45582             76.986241                   11.041753
# 45583             85.325731                   23.431058
#
#        Delivery_location_longitude  Time_Orderd  Time_Order_picked  \
# 0                        78.116106         1315               1330
# 1                        76.347589          895                905
# 2                        74.006619         1050               1060
# 3                        75.829346          560                570
# 4                        80.502929         1190               1205
# ...                            ...          ...                ...
# 45579                    75.804257          695                705
# 45580                     0.070000         1195               1210
# 45581                    80.272439         1430               1445
# 45582                    77.026241          815                820
# 45583                    85.405731         1030               1035
#
#       Weather_conditions Road_traffic_density  Vehicle_condition  \
# 0                    Fog                  Jam                  2
# 1                 Stormy                 High                  1
# 2             Sandstorms               Medium                  1
# 3             Sandstorms                  Low                  0
# 4                    Fog                  Jam                  1
# ...                  ...                  ...                ...
# 45579              Windy                 High                  1
# 45580              Windy                  Jam                  0
# 45581             Cloudy                  Low                  1
# 45582             Cloudy                 High                  0
# 45583                Fog               Medium                  2
#
#       Type_of_order Type_of_vehicle  multiple_deliveries Festival  \
# 0             Snack      motorcycle                  3.0       No
# 1              Meal      motorcycle                  1.0       No
# 2            Drinks         scooter                  1.0       No
# 3            Buffet      motorcycle                  0.0       No
# 4             Snack         scooter                  1.0       No
# ...             ...             ...                  ...      ...
# 45579          Meal      motorcycle                  0.0       No
# 45580        Buffet      motorcycle                  1.0       No
# 45581        Drinks         scooter                  0.0       No
# 45582         Snack      motorcycle                  1.0       No
# 45583         Snack         scooter                  1.0       No
#
#                 City  Order_day  Order_month  Order_year
# 0      Metropolitian         12            2        2022
# 1      Metropolitian         13            2        2022
# 2      Metropolitian          4            3        2022
# 3      Metropolitian         13            2        2022
# 4      Metropolitian         14            2        2022
# ...              ...        ...          ...         ...
# 45579  Metropolitian         24            3        2022
# 45580  Metropolitian         16            2        2022
# 45581  Metropolitian         11            3        2022
# 45582  Metropolitian          7            3        2022
# 45583  Metropolitian          2            3        2022
#
# [43853 rows x 19 columns]

# %%
y
# Out:
#        Time_taken (min)
# 0                    46
# 1                    23
# 2                    21
# 3                    20
# 4                    41
# ...                 ...
# 45579                32
# 45580                36
# 45581                16
# 45582                26
# 45583                36
#
# [43853 rows x 1 columns]

# %%
categorical_column = X.select_dtypes(include='O').columns
numerical_column = X.select_dtypes(exclude="O").columns

# %%
print("categorical columns are :-",
categorical_column)
# Out:
# categorical columns are :- Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
print("numerical_columns are :-",
numerical_column)
# Out:
# numerical_columns are :- Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Time_Orderd', 'Time_Order_picked',
#        'Vehicle_condition', 'multiple_deliveries', 'Order_day', 'Order_month',
#        'Order_year'],
#       dtype='object')

# %%
# here in this we perform a ordinal encoding so shuld collect our ranking 

categorical_column
# Out:
# Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
weather_map=['Sunny', 'Windy', 'Sandstorms', 'Cloudy', 'Stormy', 'Fog']
road_traffic_map=['Low', 'Medium', 'High', 'Jam']
type_order_map = ['Buffet', 'Drinks', 'Meal', 'Snack']
type_vehicle_map = ['electric_scooter','scooter', 'motorcycle']
festival_map = ['No', 'Yes']
city_map = ['Semi-Urban', 'Urban','Metropolitian']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# numerical pipeline 

numerical_pipeline = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('Scaler',StandardScaler())
    ]
)

categorical_pipeline = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='most_frequent')),
        ('OrdinalEncoder',OrdinalEncoder(categories=[weather_map,road_traffic_map,type_order_map,type_vehicle_map,festival_map,city_map])),
        ('scaler',StandardScaler())
    ]
)


preprocessor = ColumnTransformer([
    ('numerical_pipeline',numerical_pipeline,numerical_column),
    ('categorical_pipeline',categorical_pipeline,categorical_column)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('numerical_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('Scaler', StandardScaler())]),
#                                  Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Time_Orderd', 'Time_Order_picked',
#        'Vehicle_con...
#                                                                               'Sandstorms',
#                                                                               'Cloudy',
#                                                                               'Stormy',
#                                                                               'Fog'],
#                                                                              ['Low',
#                                                                               'Medium',
#                                                                               'High',
#                                                                               'Jam'],
#                                                                              ['Buffet',
#                                                                               'Drinks',
#                                                                               'Meal',
#                                                                               'Snack'],
#                                                                              ['electric_scooter',
#                                                                               'scooter',
#                                                                               'motorcycle'],
#                                                                              ['No',
#                                                                               'Yes'],
#                                                                              ['Semi-Urban',
#                                                                               'Urban',
#                                                                               'Metropolitian']])),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object'))])

# %%
# Train Tes split

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#        numerical_pipeline__Delivery_person_Age  \
# 0                                     0.942327
# 1                                    -0.623399
# 2                                     1.116296
# 3                                    -0.971338
# 4                                     0.420418
# ...                                        ...
# 30692                                -0.449429
# 30693                                 0.420418
# 30694                                 0.942327
# 30695                                -0.449429
# 30696                                 1.116296
#
#        numerical_pipeline__Delivery_person_Ratings  \
# 0                                         0.208048
# 1                                        -0.108615
# 2                                        -0.108615
# 3                                         0.208048
# 4                                         0.208048
# ...                                            ...
# 30692                                    -1.375265
# 30693                                    -1.058602
# 30694                                     1.158036
# 30695                                    -1.375265
# 30696                                     0.524711
#
#        numerical_pipeline__Restaurant_latitude  \
# 0                                     0.022650
# 1                                    -0.557650
# 2                                    -0.812045
# 3                                     0.164524
# 4                                    -0.641636
# ...                                        ...
# 30692                                -0.643223
# 30693                                -0.550878
# 30694                                 0.790854
# 30695                                 0.022318
# 30696                                -0.549919
#
#        numerical_pipeline__Restaurant_longitude  \
# 0                                      0.360436
# 1                                      0.324876
# 2                                      0.291956
# 3                                      0.146781
# 4                                      0.276630
# ...                                         ...
# 30692                                  0.277993
# 30693                                  0.448343
# 30694                                  0.689992
# 30695                                  0.360649
# 30696                                  0.446744
#
#        numerical_pipeline__Delivery_location_latitude  \
# 0                                            0.005383
# 1                                           -0.598840
# 2                                           -0.874297
# 3                                            0.150348
# 4                                           -0.703444
# ...                                               ...
# 30692                                       -0.703747
# 30693                                       -0.606727
# 30694                                        0.801569
# 30695                                        0.002306
# 30696                                       -0.597537
#
#        numerical_pipeline__Delivery_location_longitude  \
# 0                                             0.361690
# 1                                             0.328031
# 2                                             0.292259
# 3                                             0.146609
# 4                                             0.274080
# ...                                                ...
# 30692                                         0.275919
# 30693                                         0.446268
# 30694                                         0.687442
# 30695                                         0.360952
# 30696                                         0.447522
#
#        numerical_pipeline__Time_Orderd  numerical_pipeline__Time_Order_picked  \
# 0                             0.631428                               0.613072
# 1                             1.254220                               1.272223
# 2                             0.466571                               0.466594
# 3                             0.100222                               0.082089
# 4                            -1.951330                              -1.968603
# ...                                ...                                    ...
# 30692                        -1.530029                              -1.547479
# 30693                        -2.152821                              -2.151700
# 30694                        -2.171139                              -2.188320
# 30695                         0.631428                               0.649692
# 30696                         1.180950                               1.162365
#
#        numerical_pipeline__Vehicle_condition  \
# 0                                   1.222981
# 1                                  -1.225773
# 2                                  -1.225773
# 3                                  -0.001396
# 4                                  -0.001396
# ...                                      ...
# 30692                              -1.225773
# 30693                              -1.225773
# 30694                               1.222981
# 30695                               1.222981
# 30696                              -0.001396
#
#        numerical_pipeline__multiple_deliveries  numerical_pipeline__Order_day  \
# 0                                     0.438110                      -0.663203
# 1                                    -1.327733                       1.979126
# 2                                     2.203953                       0.255868
# 3                                     0.438110                      -1.467390
# 4                                     0.438110                       0.830287
# ...                                        ...                            ...
# 30692                                 0.438110                      -0.318551
# 30693                                 0.438110                      -1.237622
# 30694                                -1.327733                      -0.318551
# 30695                                 0.438110                      -1.352506
# 30696                                -1.327733                      -0.433435
#
#        numerical_pipeline__Order_month  numerical_pipeline__Order_year  \
# 0                             0.036101                             0.0
# 1                             0.036101                             0.0
# 2                             0.036101                             0.0
# 3                             1.867822                             0.0
# 4                             0.036101                             0.0
# ...                                ...                             ...
# 30692                         0.036101                             0.0
# 30693                         0.036101                             0.0
# 30694                         0.036101                             0.0
# 30695                         1.867822                             0.0
# 30696                         0.036101                             0.0
#
#        categorical_pipeline__Weather_conditions  \
# 0                                      0.861141
# 1                                     -1.481352
# 2                                      0.275518
# 3                                     -0.310105
# 4                                     -0.310105
# ...                                         ...
# 30692                                 -0.895729
# 30693                                  0.861141
# 30694                                 -1.481352
# 30695                                  0.275518
# 30696                                  0.861141
#
#        categorical_pipeline__Road_traffic_density  \
# 0                                        1.300067
# 1                                       -1.111253
# 2                                        1.300067
# 3                                       -0.307480
# 4                                       -1.111253
# ...                                           ...
# 30692                                    0.496294
# 30693                                   -1.111253
# 30694                                   -1.111253
# 30695                                    1.300067
# 30696                                   -1.111253
#
#        categorical_pipeline__Type_of_order  \
# 0                                -1.344809
# 1                                -1.344809
# 2                                 0.438182
# 3                                -0.453313
# 4                                 0.438182
# ...                                    ...
# 30692                             1.329678
# 30693                             1.329678
# 30694                            -0.453313
# 30695                             1.329678
# 30696                            -1.344809
#
#        categorical_pipeline__Type_of_vehicle  categorical_pipeline__Festival  \
# 0                                   0.772935                       -0.141073
# 1                                   0.772935                       -0.141073
# 2                                   0.772935                       -0.141073
# 3                                  -0.786704                       -0.141073
# 4                                  -0.786704                       -0.141073
# ...                                      ...                             ...
# 30692                               0.772935                       -0.141073
# 30693                               0.772935                       -0.141073
# 30694                              -2.346344                       -0.141073
# 30695                              -0.786704                       -0.141073
# 30696                               0.772935                       -0.141073
#
#        categorical_pipeline__City
# 0                        0.535562
# 1                        0.535562
# 2                        0.535562
# 3                        0.535562
# 4                        0.535562
# ...                           ...
# 30692                   -1.797035
# 30693                   -1.797035
# 30694                   -1.797035
# 30695                    0.535562
# 30696                   -1.797035
#
# [30697 rows x 19 columns]

# %%
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_test
# Out:
#        numerical_pipeline__Delivery_person_Age  \
# 0                                    -0.623399
# 1                                    -0.623399
# 2                                    -0.275460
# 3                                    -1.319277
# 4                                    -0.971338
# ...                                        ...
# 13151                                 1.116296
# 13152                                 0.420418
# 13153                                -0.449429
# 13154                                -0.101490
# 13155                                -1.493246
#
#        numerical_pipeline__Delivery_person_Ratings  \
# 0                                         1.158036
# 1                                        -0.108615
# 2                                         1.158036
# 3                                        -0.108615
# 4                                        -0.108615
# ...                                            ...
# 13151                                    -0.108615
# 13152                                    -1.691927
# 13153                                     1.158036
# 13154                                     0.524711
# 13155                                     0.524711
#
#        numerical_pipeline__Restaurant_latitude  \
# 0                                     1.252234
# 1                                    -2.241230
# 2                                     0.020313
# 3                                     0.028153
# 4                                    -0.556981
# ...                                        ...
# 13151                                 1.699568
# 13152                                 0.504058
# 13153                                 0.166229
# 13154                                -0.818343
# 13155                                 0.021191
#
#        numerical_pipeline__Restaurant_longitude  \
# 0                                      0.237292
# 1                                     -3.366507
# 2                                      0.363108
# 3                                      0.367982
# 4                                      0.327313
# ...                                         ...
# 13151                                  0.344923
# 13152                                  0.093220
# 13153                                  0.146843
# 13154                                  0.292818
# 13155                                  0.360400
#
#        numerical_pipeline__Delivery_location_latitude  \
# 0                                            1.290398
# 1                                           -2.378564
# 2                                           -0.002527
# 3                                            0.011164
# 4                                           -0.603592
# ...                                               ...
# 13151                                        1.772653
# 13152                                        0.502981
# 13153                                        0.154867
# 13154                                       -0.878187
# 13155                                       -0.007060
#
#        numerical_pipeline__Delivery_location_longitude  \
# 0                                             0.236169
# 1                                            -3.367144
# 2                                             0.362460
# 3                                             0.369236
# 4                                             0.328567
# ...                                                ...
# 13151                                         0.348078
# 13152                                         0.091622
# 13153                                         0.147622
# 13154                                         0.294071
# 13155                                         0.357850
#
#        numerical_pipeline__Time_Orderd  numerical_pipeline__Time_Order_picked  \
# 0                            -0.650792                              -0.650301
# 1                             0.521523                               0.503214
# 2                             0.759650                               0.741241
# 3                             0.997776                               0.979267
# 4                            -0.064635                              -0.064389
# ...                                ...                                    ...
# 13151                         1.144316                               1.144055
# 13152                         0.741332                               0.722931
# 13153                         0.759650                               0.777860
# 13154                        -0.174539                              -0.174247
# 13155                        -1.401807                              -1.382691
#
#        numerical_pipeline__Vehicle_condition  \
# 0                                  -1.225773
# 1                                   1.222981
# 2                                   1.222981
# 3                                  -1.225773
# 4                                  -0.001396
# ...                                      ...
# 13151                               1.222981
# 13152                               1.222981
# 13153                              -0.001396
# 13154                               1.222981
# 13155                              -1.225773
#
#        numerical_pipeline__multiple_deliveries  numerical_pipeline__Order_day  \
# 0                                     0.438110                      -1.237622
# 1                                     0.438110                       1.404707
# 2                                    -1.327733                       0.830287
# 3                                    -1.327733                       0.715403
# 4                                     0.438110                       0.485636
# ...                                        ...                            ...
# 13151                                -1.327733                       0.485636
# 13152                                 0.438110                       1.864242
# 13153                                -1.327733                       0.715403
# 13154                                 0.438110                       1.060055
# 13155                                 0.438110                       1.864242
#
#        numerical_pipeline__Order_month  numerical_pipeline__Order_year  \
# 0                             0.036101                             0.0
# 1                             0.036101                             0.0
# 2                             0.036101                             0.0
# 3                             0.036101                             0.0
# 4                             0.036101                             0.0
# ...                                ...                             ...
# 13151                        -1.795620                             0.0
# 13152                         0.036101                             0.0
# 13153                         0.036101                             0.0
# 13154                         0.036101                             0.0
# 13155                         0.036101                             0.0
#
#        categorical_pipeline__Weather_conditions  \
# 0                                     -1.481352
# 1                                      0.275518
# 2                                      0.275518
# 3                                     -0.310105
# 4                                      1.446764
# ...                                         ...
# 13151                                  0.861141
# 13152                                 -0.310105
# 13153                                  0.861141
# 13154                                  0.861141
# 13155                                  0.275518
#
#        categorical_pipeline__Road_traffic_density  \
# 0                                       -0.307480
# 1                                        1.300067
# 2                                        1.300067
# 3                                       -1.111253
# 4                                       -0.307480
# ...                                           ...
# 13151                                   -1.111253
# 13152                                    1.300067
# 13153                                    1.300067
# 13154                                   -0.307480
# 13155                                    0.496294
#
#        categorical_pipeline__Type_of_order  \
# 0                                 1.329678
# 1                                 0.438182
# 2                                -0.453313
# 3                                -0.453313
# 4                                -1.344809
# ...                                    ...
# 13151                            -1.344809
# 13152                            -0.453313
# 13153                             1.329678
# 13154                             0.438182
# 13155                             0.438182
#
#        categorical_pipeline__Type_of_vehicle  categorical_pipeline__Festival  \
# 0                                   0.772935                       -0.141073
# 1                                  -0.786704                       -0.141073
# 2                                  -2.346344                       -0.141073
# 3                                   0.772935                       -0.141073
# 4                                  -0.786704                       -0.141073
# ...                                      ...                             ...
# 13151                               0.772935                       -0.141073
# 13152                              -2.346344                       -0.141073
# 13153                              -0.786704                       -0.141073
# 13154                              -2.346344                       -0.141073
# 13155                               0.772935                       -0.141073
#
#        categorical_pipeline__City
# 0                       -1.797035
# 1                        0.535562
# 2                        0.535562
# 3                        0.535562
# 4                        0.535562
# ...                           ...
# 13151                    0.535562
# 13152                    0.535562
# 13153                    0.535562
# 13154                    0.535562
# 13155                    0.535562
#
# [13156 rows x 19 columns]

# %%
# model training

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_
# Out:
# array([26.35863439])

# %%
regression.coef_
# Out:
# array([[ 2.25021171e+00, -2.30044065e+00,  1.81881102e-01,
#         -1.25706470e+03, -2.91228037e-01,  1.25715539e+03,
#          3.76305833e-01, -1.06216644e+00, -1.87138139e+00,
#          1.78195960e+00,  1.21127491e-02, -3.27953933e-02,
#         -9.65627578e-11,  1.65066263e+00,  2.97133820e+00,
#         -8.44350367e-03, -1.01508460e-02,  1.40542759e+00,
#          6.65034141e-01]])

# %%
def evaluate_model(true,predicted):
    mse = mean_squared_error(true,predicted)
    mae = mean_absolute_error(true,predicted)
    r2_square =  r2_score(true,predicted)
    rmse = np.sqrt(mean_squared_error(true,predicted))

    return mse,mae,r2_square,rmse

# %%
# tran multiple models

models = {
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'ElasticNet':ElasticNet(),
    'Ridge':Ridge()
}

# %%
model_list = []
r2_list = []

for i in range(len(list(models))):
    #print(i)
    model = list(models.values())[i]
    #print(model)
    model.fit(X_train,y_train)

    # prediction 
    y_pred = model.predict(X_test)

    mse,mae,r2_square,rmse=evaluate_model(y_test,y_pred)

    #print(list(model.keys())[i])
    model_list.append(list(models.keys())[i])

    print("model training performance :- ",model)
    print("RMSE :- ",rmse)
    print("MSE :- ",mse)
    print("MAE :- ",mae)
    print("R2_SQUARED :- ",r2_square*100 ,"%")
    #print("\n")
    print("="*35)

    r2_list.append(r2_square*100)
    print(r2_list)
# Out:
# model training performance :-  LinearRegression()
# RMSE :-  6.212436697166137
# MSE :-  38.5943697162965
# MAE :-  4.9581568204077
# R2_SQUARED :-  56.19617463491187 %
# ===================================
# [56.19617463491187]
# model training performance :-  Lasso()
# RMSE :-  6.90844629951027
# MSE :-  47.72663027321713
# MAE :-  5.534498544649
# R2_SQUARED :-  45.83124447633171 %
# ===================================
# [56.19617463491187, 45.83124447633171]
# model training performance :-  ElasticNet()
# RMSE :-  6.977003555178169
# MSE :-  48.678578608968806
# MAE :-  5.606047479088461
# R2_SQUARED :-  44.750802459468176 %
# ===================================
# [56.19617463491187, 45.83124447633171, 44.750802459468176]
# model training performance :-  Ridge()
# RMSE :-  6.443924640150464
# MSE :-  41.52416476793829
# MAE :-  5.137807096227838
# R2_SQUARED :-  52.870916786655656 %
# ===================================
# [56.19617463491187, 45.83124447633171, 44.750802459468176, 52.870916786655656]

# %%
model_list
# Out:
# ['LinearRegression', 'Lasso', 'ElasticNet', 'Ridge']

# %%
r2_list
# Out:
# [56.19617463491187, 45.83124447633171, 44.750802459468176, 52.870916786655656]

# %%
dict(zip(model_list,r2_list))
# Out:
# {'LinearRegression': 56.19617463491187,
#  'Lasso': 45.83124447633171,
#  'ElasticNet': 44.750802459468176,
#  'Ridge': 52.870916786655656}
